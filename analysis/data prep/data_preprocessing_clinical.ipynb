# %% [markdown]
# # Download Dataset
# First step is to download the dataset, extract the metadata and drop constant columns (contain no information, only slow down computations).

# %%
import GEOparse
import pandas as pd

# Step 1: Download GEO dataset
gse = GEOparse.get_GEO("GSE96058", destdir="/Users/sarah/Code/bioinformatics-tool/backend/data", how="full")

# Step 2: Extract sample metadata (GSMs)
clinical_df = gse.phenotype_data

n_before = clinical_df.shape[1]
clinical_df = clinical_df.loc[:, clinical_df.nunique(dropna=False) > 1].copy()
n_after = clinical_df.shape[1]

print(f"Dropped {n_before - n_after} constant columns. Remaining columns: {n_after}")

# Set 'title' as index
clinical_df.set_index("title", inplace=True)
# Out:
# 30-Jun-2025 18:14:15 INFO GEOparse - File already exist: using local version.
# 30-Jun-2025 18:14:15 INFO GEOparse - Parsing /Users/sarah/Code/bioinformatics-tool/backend/data/GSE96058_family.soft.gz:
# 30-Jun-2025 18:14:15 DEBUG GEOparse - DATABASE: GeoMiame
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SERIES: GSE96058
# 30-Jun-2025 18:14:15 DEBUG GEOparse - PLATFORM: GPL11154
# 30-Jun-2025 18:14:15 DEBUG GEOparse - PLATFORM: GPL18573
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528079
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528080
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528081
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528082
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528083
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528084
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528085
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528086
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528087
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528088
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528089
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528090
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528091
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528092
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528093
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528094
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528095
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528096
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528097
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528098
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528099
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528100
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528101
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528102
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528103
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528104
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528105
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528106
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528107
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528108
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528109
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528110
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528111
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528112
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528113
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528114
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528115
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528116
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528117
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528118
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528119
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528120
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528121
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528122
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528123
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528124
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528125
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528126
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528127
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528128
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528129
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528130
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528131
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528132
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528133
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528134
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528135
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528136
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528137
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528138
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528139
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528140
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528141
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528142
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528143
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528144
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528145
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528146
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528147
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528148
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528149
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528150
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528151
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528152
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528153
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528154
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528155
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528156
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528157
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528158
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528159
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528160
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528161
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528162
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528163
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528164
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528165
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528166
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528167
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528168
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528169
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528170
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528171
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528172
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528173
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528174
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528175
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528176
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528177
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528178
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528179
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528180
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528181
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528182
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528183
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528184
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528185
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528186
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528187
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528188
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528189
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528190
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528191
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528192
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528193
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528194
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528195
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528196
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528197
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528198
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528199
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528200
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528201
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528202
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528203
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528204
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528205
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528206
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528207
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528208
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528209
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528210
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528211
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528212
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528213
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528214
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528215
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528216
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528217
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528218
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528219
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528220
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528221
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528222
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528223
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528224
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528225
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528226
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528227
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528228
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528229
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528230
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528231
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528232
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528233
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528234
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528235
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528236
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528237
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528238
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528239
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528240
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528241
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528242
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528243
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528244
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528245
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528246
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528247
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528248
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528249
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528250
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528251
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528252
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528253
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528254
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528255
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528256
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528257
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528258
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528259
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528260
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528261
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528262
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528263
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528264
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528265
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528266
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528267
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528268
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528269
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528270
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528271
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528272
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528273
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528274
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528275
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528276
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528277
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528278
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528279
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528280
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528281
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528282
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528283
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528284
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528285
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528286
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528287
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2528288
# 30-Jun-2025 18:14:15 DEBUG GEOparse - SAMPLE: GSM2
# characteristics_ch1.19.ki67 prediction sgc
# characteristics_ch1.20.pam50 subtype
# characteristics_ch1.21.overall survival days
# characteristics_ch1.22.overall survival event
# characteristics_ch1.23.endocrine treated
# characteristics_ch1.24.chemo treated
# platform_id
# instrument_model
# relation

# %% [markdown]
# # Data Preprocessing
#
# Preprocessing of the features that remain:
# - Numeric Features: leave as is, possibly standardize later
# - Binary Features: map to 0/1
# - Ordinal Categorical (e.g. nhg): map to 1,2,3
# - Nominal categorical (e.g. pam50 subtype): one-hot encode -> so we don't introduce an artificial order

# %%
clinical_df_cleaned = clinical_df.copy()

# Clean up column names
clinical_df_cleaned.columns = clinical_df_cleaned.columns.str.replace(r'^characteristics_ch1\.\d+\.', '', regex=True)

# %% [markdown]
# ## Columns to Drop
# - identifiers
# - duplicates

# %%
cols_to_drop = ['sample_id', 'geo_accession', 'scan-b external id', 'relation']

# Drop only if they exist (to avoid errors)
clinical_df_cleaned = clinical_df_cleaned.drop(columns=[col for col in cols_to_drop if col in clinical_df_cleaned.columns])

# %% [markdown]
# ### Instrument Model
# This is a feature that would be excluded before ML application but could be interesting during EDA (e.g. batch effects) and that is why I want to keep it for now. There are however three columns that seem to have the same consistent values with the same information ('instrument model', 'platform id' and 'instrument_model') so I check whether they have 100% match and if so, drop two of them and retain only one.

# %%
instrument_pairs = clinical_df_cleaned[['instrument model', 'platform_id']].dropna()
mapping_check = instrument_pairs.groupby('instrument model')['platform_id'].nunique()
print(mapping_check[mapping_check > 1])
# Out:
# Series([], Name: platform_id, dtype: int64)

# %%
instrument_pairs = clinical_df_cleaned[['instrument model', 'instrument_model']].dropna()
mapping_check = instrument_pairs.groupby('instrument model')['instrument_model'].nunique()
print(mapping_check[mapping_check > 1])
# Out:
# Series([], Name: instrument_model, dtype: int64)

# %% [markdown]
# Since none map to more than one platform id / model, I can drop two cols.

# %%
clinical_df_cleaned = clinical_df_cleaned.drop(columns=['platform_id', 'instrument_model'])

# %% [markdown]
# ## Numeric Columns
# no preprocessing necessary apart from transformation to numeric

# %%
numeric_cols = [
    'age at diagnosis',
    'tumor size',
    'overall survival days'
]

# %%
for col in numeric_cols:
    try:
        clinical_df_cleaned[col] = pd.to_numeric(clinical_df_cleaned[col], errors='coerce')
    except Exception as e:
        print(f"Couldn't convert {col}: {e}")

# %% [markdown]
# ## Binary Columns
# Binary columns are encoded in different ways. They should all numerically be 0 or 1 or NaN after preprocessing.

# %%
# Encode lymph node status
clinical_df_cleaned['lymph node status'] = clinical_df_cleaned['lymph node status'].map({
    'NodeNegative': 0,
    'NodePositive': 1
})

# %%
import numpy as np

binary_cols = ['er status', 'pgr status', 'her2 status', 'ki67 status', 'er prediction mgc', 'pgr prediction mgc', 'her2 prediction mgc', 'ki67 prediction mgc', 'er prediction sgc', 'pgr prediction sgc', 'her2 prediction sgc', 'ki67 prediction sgc', 'overall survival event', 'endocrine treated', 'chemo treated']

# Replace 'NA' strings with np.nan and convert to float
for col in binary_cols:
    clinical_df_cleaned[col] = clinical_df_cleaned[col].replace('NA', np.nan).astype(float)

# %% [markdown]
# ## Ordinal Columns
# Label encode -> preserve order
#
# To create a mapping, the different unique values are examined.

# %%
print(f"Nottingham Histologic Grades: {clinical_df_cleaned['nhg'].unique()}")
print(f"Nottingham Histologic Grades Prediction: {clinical_df_cleaned['nhg prediction mgc'].unique()}")
print(f"Lymph Node Group: {clinical_df_cleaned['lymph node group'].unique()}")
# Out:
# Nottingham Histologic Grades: ['G3' 'G2' 'G1' nan]
# Nottingham Histologic Grades Prediction: ['G3' 'G2']
# Lymph Node Group: ['NodeNegative' '1to3' '4toX' 'SubMicroMet' nan]

# %% [markdown]
# Comment: interesting thet the NHG Prediction MGC only has grade 2 and 3!

# %% [markdown]
# ### Lymph Node Group
# Not sure whether to one hot encode or label encode -  there is an implicit order (Node Negative < SubmicroMet y< 1to3 < 4toX) but since the boundaries are fuzzy (SubMicroMet), this could also be a problem - solution: for now, use label encoding and potentially later on if using NN go back and one-hot-encode.

# %%
ordinal_map = {
    'nhg': {'G1': 1, 'G2': 2, 'G3': 3},
    'nhg prediction mgc': {'G2': 2, 'G3': 3},
    'lymph node group': {'NodeNegative': 0, 'SubMicroMet': 1, '1to3': 2, '4toX': 3}
}

for col, mapping in ordinal_map.items():
    clinical_df_cleaned[col] = clinical_df_cleaned[col].replace('NA', np.nan)
    clinical_df_cleaned[col] = clinical_df_cleaned[col].map(mapping)

# %% [markdown]
# ## Non-Ordinal Columns
# One Hot Encode. Keep originals for now (might be useful for analyses).

# %%
cols_to_one_hot = ['last_update_date', 'instrument model', 'pam50 subtype']
clinical_df_cleaned = pd.get_dummies(clinical_df_cleaned, columns=cols_to_one_hot, prefix_sep='__', dtype=int)

# %% [markdown]
# # Flag Columns
# I want to flag columns I will not be using for ML training but would still like to keep for ETA (since they might give useful information).
# - identifiers
# - technical metadata
# - prediction outputs from papers

# %%
id_columns = [
    'last_update_date__Mar 12 2018',
    'last_update_date__May 04 2022',
    'instrument model__HiSeq 2000',
    'instrument model__NextSeq 500',
    "er prediction mgc",
    "pgr prediction mgc",
    "her2 prediction mgc",
    "ki67 prediction mgc",
    "nhg prediction mgc",
    "er prediction sgc",
    "pgr prediction sgc",
    "her2 prediction sgc",
    "ki67 prediction sgc"
]

prediction_columns = [
    col for col in clinical_df.columns if 'prediction' in col.lower()
]

excluded_columns = id_columns + prediction_columns

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from dotenv import load_dotenv

load_dotenv(dotenv_path="/Users/sarah/Code/bioinformatics-tool/analysis/.env") 

clinical_df_cleaned.to_csv(os.getenv("CLINICAL"))
